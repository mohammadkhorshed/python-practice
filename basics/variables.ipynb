# %% [markdown]
# # Python Variables Practice
#
# 🔹 This notebook contains 25 exercises (from easy to hard) to help you practice Python variables.
#
# 🔹 This notebook (only problems) was generated by ChatGPT.
#
# 🔹 The problems were solved through my own efforts.
#
# ---

# %% [markdown]
# 1. Create a variable called `name` and assign your name to it.

# %%
name = 'Mohammad'

# %% [markdown]
# 2. Assign the value 25 to a variable named `age`.

# %%
age = 25

# %% [markdown]
# 3. Create a variable `is_student` and assign it a boolean value.

# %%
is_student = True

# %% [markdown]
# 4. Assign the value 3.14 to a variable called `pi`.

# %%
pi = 3.14

# %% [markdown]
# 5. Create two variables `x` and `y`, assign any numbers, and print their sum.

# %%
x, y = 5, 20

sum_xy = x + y

print(sum_xy)
# Out:
# 25

# %% [markdown]
# 6. Swap the values of two variables `a` and `b`.

# %%
a, b = 3, 7

a, b = b, a

print(f'a: {a} & b: {b}')
# Out:
# a: 7 & b: 3

# %% [markdown]
# 7. Assign your birth year to a variable and calculate your current age.

# %%
birth_year = 2000

age = 2025 - birth_year

print('Age:', age)
# Out:
# Age: 25

# %% [markdown]
# 8. Define three variables in one line: `a`, `b`, and `c` with values 1, 2, and 3.

# %%
a, b, c = 1, 2, 3

# %% [markdown]
# 9. Create a string variable that includes both single and double quotes.

# %%
text = "I'm a Data Science student."

text
# Out:
# "I'm a Data Science student."

# %% [markdown]
# 10. Assign a multiline string to a variable named `story`.

# %%
story = """A data scientist once faced a messy, incomplete dataset—rows of missing values and noise.  
Instead of giving up, she cleaned, transformed, and modeled it with patience.  
Her insights uncovered hidden patterns that revolutionized her company’s strategy.  
Lesson: Even chaos can reveal truth, with the right analysis and perseverance."""  

print(story)
# Out:
# A data scientist once faced a messy, incomplete dataset—rows of missing values and noise.
# Instead of giving up, she cleaned, transformed, and modeled it with patience.
# Her insights uncovered hidden patterns that revolutionized her company’s strategy.
# Lesson: Even chaos can reveal truth, with the right analysis and perseverance.

# %% [markdown]
# 11. Create a variable `height_cm` and convert it to meters in another variable.

# %%
height_cm = 180

height_m = height_cm / 100

print(height_m)
# Out:
# 1.8

# %% [markdown]
# 12. Assign your first and last names to two variables, then combine them into a full name.

# %%
first_name = 'Mohammad'

last_name = 'Alam'

full_name = first_name+ ' ' + last_name

print(full_name)
# Out:
# Mohammad Alam

# %% [markdown]
# 13. Create a variable `temp_celsius` and convert it to Fahrenheit.

# %%
temp_celsius = 25

temp_fahrenheit = (temp_celsius * 9 / 5) + 32

print(temp_fahrenheit)
# Out:
# 77.0

# %% [markdown]
# 14. Create a list of your top 3 favorite colors and assign it to `colors`.

# %%
colors = ['Black', 'Navy Blue', 'Olive']

colors
# Out:
# ['Black', 'Navy Blue', 'Olive']

# %% [markdown]
# 15. Assign a dictionary of your name, age, and city to a variable `person`.

# %%
person = {
    'name'  : 'Mohammad Khorshed Alam',
    'age'   : 25,
    'city'  : 'Dhaka'
}

person
# Out:
# {'name': 'Mohammad Khorshed Alam', 'age': 25, 'city': 'Dhaka'}

# %% [markdown]
# 16. Use a variable to hold the result of `5 + 3 * 2` and print it.

# %%
a, b, c = 5, 3, 2

result = 5 + 3 * 2

result
# Out:
# 11

# %% [markdown]
# 17. Create a variable `sentence` and count the number of characters in it.

# %%
sentence = 'Data is the new oil.'

len(sentence)
# Out:
# 20

# %% [markdown]
# 18. Take a float value and assign it to a variable, then convert it to an integer.

# %%
float_value = float(input('Enter a float number: '))

int_value = int(float_value)

int_value
# Out:
# 12

# %% [markdown]
# 19. Use `input()` to ask the user's name and store it in a variable.

# %%
name = input('Name: ')

name
# Out:
# 'Mohammad'

# %% [markdown]
# 20. Define two variables, `length` and `width`, and calculate area of a rectangle.

# %%
length, width = 10, 5

area = length * width

area
# Out:
# 50

# %% [markdown]
# 21. Assign a list of numbers to a variable and find their average.

# %%
numbers = [5, 9, 7, 2, 12, 6, 11, 16]

avg = sum(numbers) / len(numbers)

avg
# Out:
# 8.5

# %% [markdown]
# 22. Store a file path in a variable and print its file extension.

# %%
file_path = 'user/variables.ipynb'

file_extension = file_path.split('.')[-1]

print('File Extension:', file_extension)
# Out:
# File Extension: ipynb

# %% [markdown]
# 23. Create a variable with a complex number and print its real and imaginary parts.

# %%
complex_num = 3+2j

real_part = complex_num.real
imaginary_part = complex_num.imag


print(f'Real part: {real_part}\nImaginary part: {imaginary_part}')
# Out:
# Real part: 3.0
# Imaginary part: 2.0

# %% [markdown]
# 24. Store the result of checking if 15 is greater than 10 in a variable.

# %%
result = 15 > 10

result
# Out:
# True

# %% [markdown]
# 25. Use a variable to build and print a formatted message using f-strings.

# %%
a, b, c = 25, 50, a+b

print(f'{c} is the sum of {a} and {b}!')
# Out:
# 75 is the sum of 25 and 50!
