# %% [markdown]
# # Python `zip()` and Unzipping Practice
#
# This notebook includes **10 exercises** (from basic to advanced) to help me master **Python's `zip()` function** and **unzipping using `zip(*zipped)`**.
#
# 🔹 This notebook (only problems) was generated by ChatGPT.
#
# 🔹 The problems were solved through my own efforts.
#
# ---

# %% [markdown]
# ### 1. Use `zip()` to combine two lists: `['a', 'b', 'c']` and `[1, 2, 3]`.

# %%
lst1 = ['a', 'b', 'c']
lst2 = [1, 2, 3]

ziped = list(zip(lst1, lst2))
print(ziped)
# Out:
# [('a', 1), ('b', 2), ('c', 3)]

# %% [markdown]
# ### 2. Create a dictionary from two lists using `zip()`: keys = ['name', 'age'], values = ['John', 25].

# %%
keys = ['name', 'age']
values = ['John', 25]

my_dict = dict(zip(keys, values))
print(my_dict)
# Out:
# {'name': 'John', 'age': 25}

# %% [markdown]
# ### 3. Zip three lists together: names, ages, and cities.

# %%
names = ['John', 'Mehmed', 'Uthman']
ages = [36, 21, 48]
cities = ['Bethany', 'Constantinople', 'Hejaz']

zipped_list = list(zip(names, ages, cities))
print(zipped_list)
# Out:
# [('John', 36, 'Bethany'), ('Mehmed', 21, 'Constantinople'), ('Uthman', 48, 'Hejaz')]

# %% [markdown]
# ### 4. Unzip a list of tuples into individual lists using `zip(*zipped)`.

# %%
unzipped_names, unzipped_ages, unzipped_cities = map(list, zip(*zipped_list))

print(unzipped_names)
print(unzipped_ages)
print(unzipped_cities)
# Out:
# ['John', 'Mehmed', 'Uthman']
# [36, 21, 48]
# ['Bethany', 'Constantinople', 'Hejaz']

# %% [markdown]
# ### 5. Combine first and last names lists into full names using `zip()` and list comprehension.

# %%
first_names = ['Sakib', 'Salman', 'Johnny', 'Al', 'Tim']
lst_names = ['Khan', 'Shah', 'Depp', 'Pacino', 'Robbins']

full_name = [f"{first.strip().title()} {last.strip().title()}" for first, last in zip(first_names, lst_names)]
print(full_name)
# Out:
# ['Sakib Khan', 'Salman Shah', 'Johnny Depp', 'Al Pacino', 'Tim Robbins']

# %% [markdown]
# ### 6. Zip a list of student names with their marks and print only those with marks above 80.

# %%
students = ['Sakib Khan', 'Salman Shah', 'Johnny Depp', 'Al Pacino', 'Tim Robbins']
marks = [75, 94, 80, 98, 86]

student_list = list(zip(students, marks))
print([student for student in student_list if student[1] > 80])
# Out:
# [('Salman Shah', 94), ('Al Pacino', 98), ('Tim Robbins', 86)]

# %% [markdown]
# ### 7. Given two lists of the same length, return a list of tuples containing their element-wise product.

# %%
lst1 = [2, 4, 6]
lst2 = [3, 5, 7]

result = [(a, b, a * b) for a, b in zip(lst1, lst2)]
print(result)
# Out:
# [(2, 3, 6), (4, 5, 20), (6, 7, 42)]

# %% [markdown]
# ### 8. Create a transpose of a 2D matrix using `zip()`.

# %%
mtx = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

zipped_mtx = [list(row) for row in zip(*mtx)]
print(zipped_mtx)
# Out:
# [[1, 4, 7], [2, 5, 8], [3, 6, 9]]

# %%
print([list(row) for row in zip(*mtx)])
# Out:
# [[1, 4, 7], [2, 5, 8], [3, 6, 9]]

# %% [markdown]
# ### 9. Use `zip()` to compare elements of two lists and return pairs where elements are equal.

# %%
lst1 = [2, 7, 4, 6, 9, 1]
lst2 = [3, 6, 4, 2, 9, 5]

print([i for i in zip(lst1, lst2) if i[0] == i [1]])
# Out:
# [(4, 4), (9, 9)]

# %% [markdown]
# ### 10. Unzip a zipped object of employee data and reconstruct the original lists.

# %%
employee_data = [('Tom', 25, 'Data Analyst'), ('Dick', 32, 'Data Scientist'), ('Harry', 40, 'Manager')]

names, ages, positions = map(list, zip(*employee_data))
print(names)
print(ages)
print(positions)
# Out:
# ['Tom', 'Dick', 'Harry']
# [25, 32, 40]
# ['Data Analyst', 'Data Scientist', 'Manager']
