# %% [markdown]
# # Python Tuples Practice
#
# This notebook includes **20 exercises** to help me master working with **Python Tuples**.
#
# 🔹 This notebook (only problems) was generated by ChatGPT.
#
# 🔹 The problems were solved through my own efforts.
#
#
#
# ---

# %% [markdown]
# ### 1. Create a tuple with numbers from 1 to 5.

# %%
tpl = tuple(range(1, 6))
print(tpl)
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# ### 2. Access the third element of a tuple.

# %%
print(tpl[2])
# Out:
# 3

# %% [markdown]
# ### 3. Slice a tuple from index 1 to 3.

# %%
print(tpl[1:4])
# Out:
# (2, 3, 4)

# %% [markdown]
# ### 4. Check if the number 10 is present in a tuple.

# %%
print(10 in tpl)
# Out:
# False

# %% [markdown]
# ### 5. Concatenate two tuples: (1, 2, 3) and (4, 5, 6).

# %%
tpl_1 = 1, 2, 3
tpl_2 = 4, 5, 6

concatenated_tpl = tpl_1 + tpl_2

print(concatenated_tpl)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# ### 6. Repeat a tuple (1, 2) three times.

# %%
tpl = 1, 2

print( tpl * 3)
# Out:
# (1, 2, 1, 2, 1, 2)

# %% [markdown]
# ### 7. Find the length of a tuple.

# %%
tpl = (1, 3, 5, 7, 9)

print(len(tpl))
# Out:
# 5

# %% [markdown]
# ### 8. Find the maximum and minimum values in a tuple of numbers.

# %%
tpl = (13, 7, 63, 29, 75, 3, 87, 55, 93, 88, 5, 4)

print(f"Maximum value: {max(tpl)}")
print(f"Minimum value: {min(tpl)}")
# Out:
# Maximum value: 93
# Minimum value: 3

# %% [markdown]
# ### 9. Convert a list [1, 2, 3] into a tuple.

# %%
lst = [1, 2, 3]

tpl = tuple(lst)

print(tpl)
# Out:
# (1, 2, 3)

# %% [markdown]
# ### 10. Count how many times an element appears in a tuple.

# %%
tpl = 1, 5, 3, 5, 1, 9, 5, 7, 3, 5

tpl.count(5)
# Out:
# 4

# %% [markdown]
# ### 11. Get the index of the first occurrence of an element.

# %%
tpl.index(5)
# Out:
# 1

# %% [markdown]
# ### 12. Unpack a tuple into separate variables.

# %%
tpl = (1, 2, 3)

a, b, c = tpl

print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ### 13. Swap two variables using tuple unpacking.

# %%
a = 12
b = 6

a, b = b, a

print(a)
print(b)
# Out:
# 6
# 12

# %% [markdown]
# ### 14. Use a tuple as a key in a dictionary.

# %%
my_dict = {
    ('Mohammad', 'Alam')    : 25,
    ('John', 'Wick')        : 32,
    ('Harry', 'Potter')     : 28
}


print(my_dict[('John', 'Wick')])
print(my_dict[('Mohammad', 'Alam')])
# Out:
# 32
# 25

# %% [markdown]
# ### 15. Iterate over a tuple and print each element.

# %%
colors = 'Black', 'Red', 'Blue', 'White', 'Green'

for color in colors:
    print(color)
# Out:
# Black
# Red
# Blue
# White
# Green

# %% [markdown]
# ### 16. Convert a string into a tuple of characters.

# %%
text = 'Pythonism'

tpl = tuple(text)

print(tpl)
# Out:
# ('P', 'y', 't', 'h', 'o', 'n', 'i', 's', 'm')

# %% [markdown]
# ### 17. Check if a tuple is empty.

# %%
# Solution-1
tpl = ()
is_empty = not tpl
print(is_empty)
# Out:
# True

# %%
# Solution-2
tpl = (1,)
print(len(tpl) == 0)
# Out:
# False

# %% [markdown]
# ### 18. Write a function that accepts a tuple of numbers and returns the sum.

# %%
def sum_of_num(tpl):
    total = 0
    for num in tpl:
        total += num
    return total

my_tpl = (25, 12, 54, 32)
sum_of_num(my_tpl)
# Out:
# 123

# %% [markdown]
# ### 19. From a tuple of strings, return the longest one.

# %%
# Solution-1
texts = ("Bangladesh", "United Sates", "Germany", "United Kingdom", "Canada", "United Arab Emirates")

longest_str = ""

for text in texts:
    if len(text) > len(longest_str):
        longest_str = text
print(longest_str)
# Out:
# United Arab Emirates

# %%
# Solution-2
texts = ("Bangladesh", "United Sates", "Germany", "United Kingdom", "Canada", "United Arab Emirates")

longest_str = max(texts, key=len)
print(longest_str)
# Out:
# United Arab Emirates

# %% [markdown]
# ### 20. Given a tuple of (name, age) pairs, return a list of names where age > 25.

# %%
people = (("Mohammad", 25), ("John", 36), ("Rakib", 22), ("Ahmed", 26), ("Rajib", 33))

name_list = [person[0] for person in people if person[1] > 25]

print(name_list)
# Out:
# ['John', 'Ahmed', 'Rajib']
